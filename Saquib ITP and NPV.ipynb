# %%
#Importing Numpy and Pandas Libraries:
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

#Importing Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load csv file 
df1 = pd.read_csv('ramen-ratings.csv')

#import os
#os.listdir('')
#df1=pd.read_csv('')

# %%
##Q1. What is the packing style that is more prevalent as part of the Top 10

# %%
df1.groupby('Style').count()['Top Ten']
# Out:
# Style
# Bar      0
# Bowl     0
# Box      0
# Can      0
# Cup      0
# Pack    33
# Tray     4
# Name: Top Ten, dtype: int64

# %%
df1.groupby('Style').count()['Top Ten'][df1.groupby('Style').count()['Top Ten']!=0]
# Out:
# Style
# Pack    33
# Tray     4
# Name: Top Ten, dtype: int64

# %%
df3=df1.groupby('Style').count()['Top Ten'][df1.groupby('Style').count()['Top Ten']!=0]

print("The packing style that is most prevalent as part of Top Ten are: ", c.index[0] +',', c.index[1])
# Out:
# The packing style that is most prevalent as part of Top Ten are:  Pack, Tray

# %%
df4=DataFrame({'Style':[df3.index[0],df3.index[1]],
            'Count_Top_Ten':[df3.values[0],df3.values[1]]})

# %%
df4
# Out:
#   Style  Count_Top_Ten
# 0   Bar              0
# 1  Bowl              0

# %%
Top_Ten_Packing_Styles=DataFrame(df1[df1['Top Ten'].notnull()])

# %%
Top_Ten_Packing_Styles
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1757       823             Paldo
# 1865       715           Indomie
# ...

# %%
Top_Ten_Packing_Styles['Style'].value_counts().plot(kind='bar')
plt.ylabel('Count')
plt.xlabel('Style')
plt.title('Top Ten Bar Graph')
plt.show()

# %%
## Adding mean() for Null values in the Stars
df1['Stars'] = df1['Stars'].fillna(df1['Stars'].mean())

# %%
df2 =df1.dropna()
df2.info()

# %%
df1 =df2.drop_duplicates()

# %%
df1.nunique()
# Out:
# Review #    2580
# Brand        355
# Variety     2413
# Style          7
# Country       38
# Stars         11
# Top Ten       37
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   float64
#  6   Top Ten   37 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 141.2+ KB

# %%
df1=df1.replace({'United States':'USA','Sarawak':'Malaysia'})
df1['Country'].value_counts()

# %%
df1['Test']=0  #initializing another column.. couldn't succeed with replace.
df1.loc[(df1['Stars'] %1<0.25), 'Test']=np.floor(df1['Stars'])
df1.loc[(df1['Stars'] %1>=0.25) & (df1['Stars'] %1<=0.5), 'Test'] = np.floor(df1['Stars'])+0.5
df1.loc[(df1['Stars'] %1>0.5) & (df1['Stars'] %1<0.75), 'Test'] = np.floor(df1['Stars'])+0.5
df1.loc[(df1['Stars'] %1>=0.75) & (df1['Stars'] %1<1.0), 'Test'] = np.ceil(df1['Stars'])
df1['Stars']=df1['Test']
del df1['Test']

# %%
rank_2_3
# Out:
#       Review #     Brand                                   Variety Style  \
# 2         2578    Nissin             Cup Noodles Chicken Vegetable   Cup
# 3         2577   Wei Lih             GGE Ramen Snack Tomato Flavor  Pack
# 9         2571      KOKA     The Original Spicy Stir-Fried Noodles  Pack
# 50        2530    Ottogi  Ppushu Ppushu Noodle Snack Honey Butter   Pack
# 76        2504  Nongshim                               Shin Ramyun  Pack
# ...        ...       ...                                       ...   ...
# 2571         9     Sutah                                Cup Noodle   Cup
# 2572         8    Tung-I          Chinese Beef Instant Rice Noodle  Pack
# 2574         6     Vifon                                  Nam Vang  Pack
# 2577         3   Wai Wai                            Tom Yum Shrimp  Pack
# 2578         2   Wai Wai                      Tom Yum Chili Flavor  Pack
#
#           Country  Stars Top Ten
# 2             USA    2.5     NaN
# ...

# %%
## Q.4 Get a list of brands which have rating between 2-3
##rephrase - Get a count of Brands based on Star values
rank_2_3=df1[(df1['Stars'] >= 0) & (df1['Stars'] <= 5)]
rank_2_3['Stars'].value_counts().plot(kind='bar')
plt.ylabel('Count')
plt.xlabel('Stars')
plt.axvline(rank_2_3['Stars'].mean())
plt.title('Count of Brands by Stars')
plt.show()

# %%
sns.distplot(rank_2_3['Stars'])
plt.show()

# %%
plt.axvline(df1['total_bill'].mean())

# %%
##Sample
#g=a[a['Top Ten'].notnull()]
##h=DataFrame(g.groupby(['Country','Brand']).count()['Top Ten'].notnull())
#h=DataFrame(g.groupby(['Brand','Country']).count()['Stars'])
#h=DataFrame(g.groupby(['Country','Brand']).count()['Top Ten'])

# %%
## Reduce Function Lambda
# Reduce is defined in functool modules, we need to import from functools
from functools import reduce

#Python’s reduce() is a function that implements a mathematical technique called folding or reduction
#reduce() stores the intermediate result and only returns the final summation value


l1 =[1,2,3,4,5]

#accumulate() returns a iterator containing the intermediate results. 
#The last number of the iterator returned is summation value of the list.

#Difference between reduce and accumulate()
#reduce(fun,seq) takes function as 1st and sequence as 2nd argument. 
#In contrast accumulate(seq,fun) takes sequence as 1st argument and function as 2nd argument.

# %%
reduce(lambda x,y : x+y, l1)
reduce(function, sequence[, initial]) -> value

Apply a function of two arguments cumulatively to the items of a sequence,
from left to right, so as to reduce the sequence to a single value.
For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
of the sequence in the calculation, and serves as a default when the
sequence is empty.
Type:      builtin_function_or_method
# Out:
#   File "<ipython-input-40-48bd13af0041>", line 2
#     reduce(function, sequence[, initial]) -> value
#                               ^
# SyntaxError: invalid syntax

# %%
#Examples:
#Define a list
l1 =[1,2,3,4,5]

reduce(lambda x,y : x+y, l1)
reduce(lambda x,y : x-y, [1,3,5,6])
reduce(lambda x,y : x*y, l1)
reduce(lambda x,y : x/y, l1)

#reduce can also be used using the operator
import operator

reduce(operator.add,l1)
reduce(operator.sub,l1)
reduce(operator.mul,l1)
# Out:
# 120
